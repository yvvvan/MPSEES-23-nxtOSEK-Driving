# %% [markdown]
# ## Generate a test trajectory

# %%
import numpy as np

# %%
mu, sigma = 0, 0.02 # mean and standard deviation
s = np.random.normal(mu, sigma)

# %%
xs =[]
ys = []
zs = []
ls = []
ms = []
rs = []

# for i in range (4,10,2):
#     x = 0.0 + np.random.normal(mu, sigma)
#     y = i/10 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     if i == 0:
#         zs.append(True)
#         ls.append(True)
#         ms.append(True)
#         rs.append(True)
#     else: 
#         zs.append(False)
#         ls.append(False)
#         ms.append(False)
#         rs.append(False)

# for i in range (0,-20,-2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = 1.0 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     if i == 0:
#         zs.append(True)
#         ls.append(True)
#         ms.append(False)
#         rs.append(True)
#     else: 
#         zs.append(False)
#         ls.append(False)
#         ms.append(False)
#         rs.append(False)

# for i in range (-20,-10,2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = round(1.0-2-i/10,1) + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     zs.append(False)
#     ls.append(False)
#     ms.append(False)
#     rs.append(False)

# for i in range (-10,0,2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = 0.0 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     zs.append(False)
#     ls.append(False)
#     ms.append(False)
#     rs.append(False)

# for i in range (-4,10,2):
#     x = 0.0 + np.random.normal(mu, sigma)
#     y = i/10 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     if i == -2:
#         zs.append(True)
#         ls.append(True)
#         ms.append(True)
#         rs.append(True)
#     else: 
#         zs.append(False)
#         ls.append(False)
#         ms.append(False)
#         rs.append(False)

# for i in range (0,-20,-2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = 1.0 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     if i == 0:
#         zs.append(True)
#         ls.append(True)
#         ms.append(False)
#         rs.append(True)
#     else: 
#         zs.append(False)
#         ls.append(False)
#         ms.append(False)
#         rs.append(False)

# for i in range (-20,-10,2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = round(1.0-2-i/10,1) + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     zs.append(False)
#     ls.append(False)
#     ms.append(False)
#     rs.append(False)

# for i in range (-10,0,2):
#     x = i/10 + np.random.normal(mu, sigma)
#     y = 0.0 + np.random.normal(mu, sigma)
#     xs.append(x) 
#     ys.append(y)
#     zs.append(False)
#     ls.append(False)
#     ms.append(False)
#     rs.append(False)

# loop 1
for i in range (8,0,-2):
    x = 0.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 10:
        zs.append(True)
        ls.append(False)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (0,10,2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 0.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(True)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (10,20,2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 0.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 10:
        zs.append(True)
        ls.append(False)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (0,10,2):
    x = 2.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(True)
        ms.append(False)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (20,0,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

for i in range (10,0,-2):
    x = 0.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 10:
        zs.append(True)
        ls.append(True)
        ms.append(True)
        rs.append(False)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

# loop 2
for i in range (0,-10,-2):
    x = 0.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(True)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (0,10,2):
    x = i/10 + np.random.normal(mu, sigma)
    y = -1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

for i in range (-10,0,2):
    x = 1.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == -10:
        zs.append(True)
        ls.append(True)
        ms.append(True)
        rs.append(False)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (10,0,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 0.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 10:
        zs.append(True)
        ls.append(True)
        ms.append(False)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

# traj 3
for i in range (0,-10,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 0.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(True)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

for i in range (-10,-20,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = round(1.0-2-i/10,1) + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

for i in range (-20,0,2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

# traj 4
for i in range (0,20,2):
    x = i/10 + np.random.normal(mu, sigma)
    y = 1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(False)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)
    
for i in range (10,0,-2):
    x = 2.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

for i in range (0,-4,-2):
    x = 2.0 + np.random.normal(mu, sigma)
    y = i/10 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 0:
        zs.append(True)
        ls.append(False)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

xs.append(1.8+ np.random.normal(mu, sigma)) 
ys.append(-0.6+ np.random.normal(mu, sigma))
xs.append(1.6+ np.random.normal(mu, sigma)) 
ys.append(-0.8+ np.random.normal(mu, sigma))
xs.append(1.4+ np.random.normal(mu, sigma)) 
ys.append(-1.0+ np.random.normal(mu, sigma))
zs.append(False)
ls.append(False)
ms.append(False)
rs.append(False)
zs.append(False)
ls.append(False)
ms.append(False)
rs.append(False)
zs.append(False)
ls.append(False)
ms.append(False)
rs.append(False)

for i in range (14,10,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = -1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    zs.append(False)
    ls.append(False)
    ms.append(False)
    rs.append(False)

for i in range (10,0,-2):
    x = i/10 + np.random.normal(mu, sigma)
    y = -1.0 + np.random.normal(mu, sigma)
    xs.append(x) 
    ys.append(y)
    if i == 10:
        zs.append(True)
        ls.append(False)
        ms.append(True)
        rs.append(True)
    else: 
        zs.append(False)
        ls.append(False)
        ms.append(False)
        rs.append(False)

zs.append(False)
ls.append(False)
ms.append(False)
rs.append(False)

# %%
import numpy as np
import matplotlib.pyplot as plt

pos_x= xs
pos_y= ys



plt.plot(pos_x, pos_y,c='g')

plt.scatter(pos_x[0], pos_y[0])
plt.scatter(pos_x[-1], pos_y[-1])
plt.show()

# %%
for i in range(len(xs)):
    print(xs[i], ys[i],zs[i+1],ls[i+1],ms[i+1],rs[i+1])
# Out:
# -0.02074471113091644 0.7839862650005963 False False False False
# 0.0015059529717507492 0.6020625676560857 False False False False
# 0.014877146348719401 0.37678809179995604 False False False False
# 0.023078677214791808 0.21333445814775878 True True True True
# -0.02676259061683059 -0.0011040588586165637 False False False False
# 0.18453256180049632 0.025244361958585114 False False False False
# 0.37826906542409383 0.009534205003636515 False False False False
# 0.5917227333224829 0.03714519971147908 False False False False
# 0.7820863562969573 0.016728626084483045 True False True True
# 0.9813925672566086 -0.0022598179185611225 False False False False
# 1.1754207677719632 -0.03568296164530461 False False False False
# 1.3945542836900404 0.028792062121639827 False False False False
# 1.618679484879241 0.025680119274125456 False False False False
# 1.833950258103827 -0.0155873796954293 True True False True
# 2.001426573265002 -0.010858258255773195 False False False False
# ...
