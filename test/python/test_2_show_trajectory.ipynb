# %% [markdown]
# ## show the keyframe from orb

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pos_1 = []
pos_2 = []
pos_3 = []
pos_4 = []
cnt = 0

path = 1
slice = 0

f = open("KeyFrameTrajectory%d.txt"%path, "r")
for line in f:
    if line == "\n":
        cnt += 1
        continue
    if cnt == slice:
        data = line.split(' ')
        if path == 0:
            pos_1.append(float(data[1]))
            pos_2.append(float(data[2]))
            pos_3.append(float(data[3]))
        else:
            pos_1.append(float(data[0]))
            pos_2.append(float(data[1]))
            pos_3.append(float(data[2])) 

# path/slice
# 0 := 306 points, laptop cam
# 1 := 520 points, pi with a good trajctory "Γ"-shape
# 2 := 222 points, pi trajctory "C"-shape
# 3 := 410 points, pi good trajctory "F"-shape
# 4/0 := 247 points, pi setting
# 4/1 := 16 points, pi setting
# 4/2 := 10 points, pi setting
# 4/3 := 19 points, pi setting
# 5 := 367 points, pi setting
# 6 := 85 points, pi setting?
# 7 := 55 points, pi setting?

# %%
len(pos_1)
# Out:
# 520

# %%
pos_x= np.array(pos_1)
pos_y= np.array(pos_2)
pos_z= np.array(pos_3)



plt.plot(pos_x, pos_y,c='g')
plt.scatter(pos_x[0], pos_y[0])
plt.scatter(pos_x[-1], pos_y[-1])

plt.show()

# %%
# Plot
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
ax.plot(pos_1, pos_2, pos_3, lw=2)

ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")

plt.show()
# Out:
# c:\Users\yfdon\anaconda3\envs\play\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   after removing the cwd from sys.path.

# %%
pos_1 = []
pos_2 = []
f = open("testTrajectory.txt", "r")
for line in f:
    if line == "\n":
        continue
    else:
        data = line.split(' ')
        pos_1.append(float(data[0]))
        pos_2.append(float(data[1]))

# %%
pos_x= np.array(pos_1)
pos_y= np.array(pos_2)



plt.plot(pos_x, pos_y,c='g')

plt.scatter(pos_x[0], pos_y[0])
plt.scatter(pos_x[-1], pos_y[-1])
plt.show()
